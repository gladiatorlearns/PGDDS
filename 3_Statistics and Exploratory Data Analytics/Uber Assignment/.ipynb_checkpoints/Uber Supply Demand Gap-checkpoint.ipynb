# %% [markdown]
# #       Uber Supply Demand Gap
# ###       By : Balakrishna Gadiyar
# ##        Purpose - This Solution document highlights the problem areas where uber is facing the supply demand gap

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy,pandas and matplotlib packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Source - Load the companies text file.

uber = pd.read_csv('Uber Request Data.csv',sep=",")

# Verify the uploaded Data frame
uber.head(25)
# Out:
#     Request id Pickup point  Driver id          Status    Request timestamp  \
# 0          619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1          867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2         1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3         2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4         3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 5         3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6         4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# 7         5510      Airport        1.0  Trip Completed  15-07-2016 05:11:52
# 8         6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9          267         City        2.0  Trip Completed       11/7/2016 6:46
# 10        1467      Airport        2.0  Trip Completed       12/7/2016 5:08
# 11        1983         City        2.0  Trip Completed      12/7/2016 12:30
# 12        2784      Airport        2.0  Trip Completed  13-07-2016 04:49:20
# 13        3075         City        2.0  Trip Completed  13-07-2016 08:02:53
# 14        3379         City        2.0  Trip Completed  13-07-2016 14:23:02
# 15        3482      Airport        2.0  Trip Completed  13-07-2016 17:23:18
# 16        4652         City        2.0  Trip Completed  14-07-2016 12:01:02
# 17        5335      Airport        2.0  Trip Completed  14-07-2016 22:24:13
# 18         535      Airport        3.0  Trip Completed      11/7/2016 10:00
# 19         960      Airport        3.0  Trip Completed      11/7/2016 18:45
# 20        1934      Airport        3.0  Trip Completed      12/7/2016 11:17
# 21        2083      Airport        3.0  Trip Completed      12/7/2016 15:46
# 22        2211      Airport        3.0  Trip Completed      12/7/2016 18:00
# 23        3096      Airport        3.0  Trip Completed  13-07-2016 08:17:29
# 24        3881      Airport        3.0  Trip Completed  13-07-2016 21:54:18
#
#          Drop timestamp
# 0       11/7/2016 13:00
# 1       11/7/2016 18:47
# 2        12/7/2016 9:58
# 3       12/7/2016 22:03
# 4   13-07-2016 09:25:47
# 5   13-07-2016 22:28:59
# 6   14-07-2016 07:13:15
# 7   15-07-2016 06:07:52
# 8   15-07-2016 18:50:51
# 9        11/7/2016 7:25
# 10       12/7/2016 6:02
# 11      12/7/2016 12:57
# 12  13-07-2016 05:23:03
# 13  13-07-2016 09:16:19
# 14  13-07-2016 15:35:18
# 15  13-07-2016 18:20:51
# 16  14-07-2016 12:36:46
# 17  14-07-2016 23:18:52
# 18      11/7/2016 10:31
# 19      11/7/2016 19:23
# 20      12/7/2016 12:23
# 21      12/7/2016 16:40
# 22      12/7/2016 18:28
# 23  13-07-2016 09:22:37
# 24  13-07-2016 22:51:23

# %%
# Data Source Analysis - Check the dataframe structure
uber.shape
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
# Request id           6745 non-null int64
# Pickup point         6745 non-null object
# Driver id            4095 non-null float64
# Status               6745 non-null object
# Request timestamp    6745 non-null object
# Drop timestamp       2831 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.2+ KB

# %%
# Data Cleaning - Date formats are not alligned, so replacing / with -
uber['Request timestamp']=uber['Request timestamp'].str.replace("/","-",case=False)
uber['Drop timestamp']=uber['Drop timestamp'].str.replace("/","-",case=False)

# Revalidating the data frame after aligning datetime fields
uber.head(25)
# Out:
#     Request id Pickup point  Driver id          Status    Request timestamp  \
# 0          619      Airport        1.0  Trip Completed      11-7-2016 11:51
# 1          867      Airport        1.0  Trip Completed      11-7-2016 17:57
# 2         1807         City        1.0  Trip Completed       12-7-2016 9:17
# 3         2532      Airport        1.0  Trip Completed      12-7-2016 21:08
# 4         3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 5         3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6         4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# 7         5510      Airport        1.0  Trip Completed  15-07-2016 05:11:52
# 8         6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9          267         City        2.0  Trip Completed       11-7-2016 6:46
# 10        1467      Airport        2.0  Trip Completed       12-7-2016 5:08
# 11        1983         City        2.0  Trip Completed      12-7-2016 12:30
# 12        2784      Airport        2.0  Trip Completed  13-07-2016 04:49:20
# 13        3075         City        2.0  Trip Completed  13-07-2016 08:02:53
# 14        3379         City        2.0  Trip Completed  13-07-2016 14:23:02
# 15        3482      Airport        2.0  Trip Completed  13-07-2016 17:23:18
# 16        4652         City        2.0  Trip Completed  14-07-2016 12:01:02
# 17        5335      Airport        2.0  Trip Completed  14-07-2016 22:24:13
# 18         535      Airport        3.0  Trip Completed      11-7-2016 10:00
# 19         960      Airport        3.0  Trip Completed      11-7-2016 18:45
# 20        1934      Airport        3.0  Trip Completed      12-7-2016 11:17
# 21        2083      Airport        3.0  Trip Completed      12-7-2016 15:46
# 22        2211      Airport        3.0  Trip Completed      12-7-2016 18:00
# 23        3096      Airport        3.0  Trip Completed  13-07-2016 08:17:29
# 24        3881      Airport        3.0  Trip Completed  13-07-2016 21:54:18
#
#          Drop timestamp
# 0       11-7-2016 13:00
# 1       11-7-2016 18:47
# 2        12-7-2016 9:58
# 3       12-7-2016 22:03
# 4   13-07-2016 09:25:47
# 5   13-07-2016 22:28:59
# 6   14-07-2016 07:13:15
# 7   15-07-2016 06:07:52
# 8   15-07-2016 18:50:51
# 9        11-7-2016 7:25
# 10       12-7-2016 6:02
# 11      12-7-2016 12:57
# 12  13-07-2016 05:23:03
# 13  13-07-2016 09:16:19
# 14  13-07-2016 15:35:18
# 15  13-07-2016 18:20:51
# 16  14-07-2016 12:36:46
# 17  14-07-2016 23:18:52
# 18      11-7-2016 10:31
# 19      11-7-2016 19:23
# 20      12-7-2016 12:23
# 21      12-7-2016 16:40
# 22      12-7-2016 18:28
# 23  13-07-2016 09:22:37
# 24  13-07-2016 22:51:23

# %%
# Data Cleaning - Date time fields are not aligned. Converting them to date time fields
uber['Request timestamp']=pd.to_datetime(uber['Request timestamp'])
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# 15          3482      Airport        2.0     Trip Completed
# 16          4652         City        2.0     Trip Completed
# 17          5335      Airport        2.0     Trip Completed
# 18           535      Airport        3.0     Trip Completed
# 19           960      Airport        3.0     Trip Completed
# 20          1934      Airport        3.0     Trip Completed
# 21          2083      Airport        3.0     Trip Completed
# 22          2211      Airport        3.0     Trip Completed
# 23          3096      Airport        3.0     Trip Completed
# 24          3881      Airport        3.0     Trip Completed
# 25          5254         City        3.0     Trip Completed
# 26          5434         City        3.0     Trip Completed
# 27          5916         City        3.0     Trip Completed
# 28           669         City        4.0     Trip Completed
# 29          1567      Airport        4.0     Trip Completed
# ...          ...          ...        ...                ...
# 6715        6683         City        NaN  No Cars Available
# 6716        6686      Airport        NaN  No Cars Available
# 6717        6688      Airport        NaN  No Cars Available
# 6718        6689      Airport        NaN  No Cars Available
# 6719        6693         City        NaN  No Cars Available
# 6720        6696         City        NaN  No Cars Available
# 6721        6697      Airport        NaN  No Cars Available
# 6722        6709      Airport        NaN  No Cars Available
# 6723        6706      Airport        NaN  No Cars Available
# 6724        6708         City        NaN  No Cars Available
# 6725        6713         City        NaN  No Cars Available
# 6726        6715         City        NaN  No Cars Available
# 6727        6716         City        NaN  No Cars Available
# 6728        6718      Airport        NaN  No Cars Available
# 6729        6720         City        NaN  No Cars Available
# 6730        6722      Airport        NaN  No Cars Available
# 6731        6725      Airport        NaN  No Cars Available
# 6732        6728         City        NaN  No Cars Available
# 6733        6730      Airport        NaN  No Cars Available
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6737        6740         City        NaN  No Cars Available
# 6738        6746         City        NaN  No Cars Available
# 6739        6739         City        NaN  No Cars Available
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp  Duration
# 0    2016-11-07 11:51:00 2016-11-07 13:00:00      69.0
# 1    2016-11-07 17:57:00 2016-11-07 18:47:00      50.0
# 2    2016-12-07 09:17:00 2016-12-07 09:58:00      41.0
# 3    2016-12-07 21:08:00 2016-12-07 22:03:00      55.0
# 4    2016-07-13 08:33:16 2016-07-13 09:25:47      52.0
# 5    2016-07-13 21:57:28 2016-07-13 22:28:59      31.0
# 6    2016-07-14 06:15:32 2016-07-14 07:13:15      57.0
# 6742 2016-07-15 23:52:06                 NaT       NaN
# 6743 2016-07-15 23:54:39                 NaT       NaN
# 6744 2016-07-15 23:55:03                 NaT       NaN
#
# [6745 rows x 7 columns]

# %%
# Derive Metrics - Pick the hour from request timestamp. 
uber['Requested Hour']=uber['Request timestamp'].dt.hour

# Creating function to generate slots based on requested hour.
# 0:00 - 6:00 - Early Morning - EM
# 6:00 - 10:00 - Morning - M
# 10:00 - 16:000 - DayTime - D
# 16:00- 21:00 - Evening - E
# 21:00 - 0:00 -  Late Evening or Night - N

def validate(df):
    if df['Requested Hour'] <= 6:
        return "EM"
    if df['Requested Hour'] <= 10:
        return "M"
    if df['Requested Hour'] <= 16:
        return "D"
    if df['Requested Hour'] <= 21:
        return "E"
    if df['Requested Hour'] <= 23:
        return "N"

# Applying the function to create new column - slots.  
uber['slot']=uber.apply(validate,axis=1)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# 15          3482      Airport        2.0     Trip Completed
# 16          4652         City        2.0     Trip Completed
# 17          5335      Airport        2.0     Trip Completed
# 18           535      Airport        3.0     Trip Completed
# 19           960      Airport        3.0     Trip Completed
# 20          1934      Airport        3.0     Trip Completed
# 21          2083      Airport        3.0     Trip Completed
# 22          2211      Airport        3.0     Trip Completed
# 23          3096      Airport        3.0     Trip Completed
# 24          3881      Airport        3.0     Trip Completed
# 25          5254         City        3.0     Trip Completed
# 26          5434         City        3.0     Trip Completed
# 27          5916         City        3.0     Trip Completed
# 28           669         City        4.0     Trip Completed
# 29          1567      Airport        4.0     Trip Completed
# ...          ...          ...        ...                ...
# 6715        6683         City        NaN  No Cars Available
# 6716        6686      Airport        NaN  No Cars Available
# 6717        6688      Airport        NaN  No Cars Available
# 6718        6689      Airport        NaN  No Cars Available
# 6719        6693         City        NaN  No Cars Available
# 6720        6696         City        NaN  No Cars Available
# 6721        6697      Airport        NaN  No Cars Available
# 6722        6709      Airport        NaN  No Cars Available
# 6723        6706      Airport        NaN  No Cars Available
# 6724        6708         City        NaN  No Cars Available
# 6725        6713         City        NaN  No Cars Available
# 6726        6715         City        NaN  No Cars Available
# 6727        6716         City        NaN  No Cars Available
# 6728        6718      Airport        NaN  No Cars Available
# 6729        6720         City        NaN  No Cars Available
# 6730        6722      Airport        NaN  No Cars Available
# 6731        6725      Airport        NaN  No Cars Available
# 6732        6728         City        NaN  No Cars Available
# 6733        6730      Airport        NaN  No Cars Available
# 6718 2016-07-15 22:43:46                 NaT       NaN              22    N
# 6719 2016-07-15 22:49:33                 NaT       NaN              22    N
# 6720 2016-07-15 22:49:45                 NaT       NaN              22    N
# 6721 2016-07-15 22:51:18                 NaT       NaN              22    N
# 6722 2016-07-15 22:56:00                 NaT       NaN              22    N
# 6723 2016-07-15 22:58:15                 NaT       NaN              22    N
# 6724 2016-07-15 23:03:23                 NaT       NaN              23    N
# 6725 2016-07-15 23:08:14                 NaT       NaN              23    N
# 6726 2016-07-15 23:11:41                 NaT       NaN              23    N
# 6727 2016-07-15 23:14:36                 NaT       NaN              23    N
# 6728 2016-07-15 23:14:39                 NaT       NaN              23    N
# 6729 2016-07-15 23:16:48                 NaT       NaN              23    N
# 6730 2016-07-15 23:18:21                 NaT       NaN              23    N
# 6731 2016-07-15 23:21:53                 NaT       NaN              23    N
# 6732 2016-07-15 23:26:50                 NaT       NaN              23    N
# 6733 2016-07-15 23:27:55                 NaT       NaN              23    N
# 6734 2016-07-15 23:35:50                 NaT       NaN              23    N
# 6735 2016-07-15 23:39:15                 NaT       NaN              23    N
# 6736 2016-07-15 23:42:51                 NaT       NaN              23    N
# 6737 2016-07-15 23:43:54                 NaT       NaN              23    N
# 6738 2016-07-15 23:46:03                 NaT       NaN              23    N
# 6739 2016-07-15 23:46:20                 NaT       NaN              23    N
# 6740 2016-07-15 23:49:03                 NaT       NaN              23    N
# 6741 2016-07-15 23:50:05                 NaT       NaN              23    N
# 6742 2016-07-15 23:52:06                 NaT       NaN              23    N
# 6743 2016-07-15 23:54:39                 NaT       NaN              23    N
# 6744 2016-07-15 23:55:03                 NaT       NaN              23    N
#
# [6745 rows x 9 columns]

# %%
# Derive metrics- Create new ride types column to ease analysis

def ridetype(df):
    if df['Pickup point'] =='Airport':
        return "Towards City"
    if df['Pickup point'] =='City':
        return "Towards Airport"

# Applying the function to create new column - slots.  
uber['Ride Type']=uber.apply(ridetype,axis=1)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# 15          3482      Airport        2.0     Trip Completed
# 16          4652         City        2.0     Trip Completed
# 17          5335      Airport        2.0     Trip Completed
# 18           535      Airport        3.0     Trip Completed
# 19           960      Airport        3.0     Trip Completed
# 20          1934      Airport        3.0     Trip Completed
# 21          2083      Airport        3.0     Trip Completed
# 22          2211      Airport        3.0     Trip Completed
# 23          3096      Airport        3.0     Trip Completed
# 24          3881      Airport        3.0     Trip Completed
# 25          5254         City        3.0     Trip Completed
# 26          5434         City        3.0     Trip Completed
# 27          5916         City        3.0     Trip Completed
# 28           669         City        4.0     Trip Completed
# 29          1567      Airport        4.0     Trip Completed
# ...          ...          ...        ...                ...
# 6715        6683         City        NaN  No Cars Available
# 6716        6686      Airport        NaN  No Cars Available
# 6717        6688      Airport        NaN  No Cars Available
# 6718        6689      Airport        NaN  No Cars Available
# 6719        6693         City        NaN  No Cars Available
# 6720        6696         City        NaN  No Cars Available
# 6721        6697      Airport        NaN  No Cars Available
# 6722        6709      Airport        NaN  No Cars Available
# 6723        6706      Airport        NaN  No Cars Available
# 6724        6708         City        NaN  No Cars Available
# 6725        6713         City        NaN  No Cars Available
# 6726        6715         City        NaN  No Cars Available
# 6727        6716         City        NaN  No Cars Available
# 6728        6718      Airport        NaN  No Cars Available
# 6729        6720         City        NaN  No Cars Available
# 6730        6722      Airport        NaN  No Cars Available
# 6731        6725      Airport        NaN  No Cars Available
# 6732        6728         City        NaN  No Cars Available
# 6733        6730      Airport        NaN  No Cars Available
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6737        6740         City        NaN  No Cars Available
# 6738        6746         City        NaN  No Cars Available
# 6739        6739         City        NaN  No Cars Available
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp  Duration  Requested Hour slot  \
# 0    2016-11-07 11:51:00 2016-11-07 13:00:00      69.0              11    D
# 1    2016-11-07 17:57:00 2016-11-07 18:47:00      50.0              17    E
# 2    2016-12-07 09:17:00 2016-12-07 09:58:00      41.0               9    M
# 3    2016-12-07 21:08:00 2016-12-07 22:03:00      55.0              21    E
# 4    2016-07-13 08:33:16 2016-07-13 09:25:47      52.0               8    M
# 5    2016-07-13 21:57:28 2016-07-13 22:28:59      31.0              21    E
# 6    2016-07-14 06:15:32 2016-07-14 07:13:15      57.0               6   EM
# 7    2016-07-15 05:11:52 2016-07-15 06:07:52      56.0               5   EM
# 8    2016-07-15 17:57:27 2016-07-15 18:50:51      53.0              17    E
# 9    2016-11-07 06:46:00 2016-11-07 07:25:00      39.0               6   EM
# 10   2016-12-07 05:08:00 2016-12-07 06:02:00      54.0               5   EM
# 11   2016-12-07 12:30:00 2016-12-07 12:57:00      27.0              12    D
# 12   2016-07-13 04:49:20 2016-07-13 05:23:03      33.0               4   EM
# 13   2016-07-13 08:02:53 2016-07-13 09:16:19      73.0               8    M
# 14   2016-07-13 14:23:02 2016-07-13 15:35:18      72.0              14    D
# 15   2016-07-13 17:23:18 2016-07-13 18:20:51      57.0              17    E
# 16   2016-07-14 12:01:02 2016-07-14 12:36:46      35.0              12    D
# 17   2016-07-14 22:24:13 2016-07-14 23:18:52      54.0              22    N
# 18   2016-11-07 10:00:00 2016-11-07 10:31:00      31.0              10    M
# 19   2016-11-07 18:45:00 2016-11-07 19:23:00      38.0              18    E
# 20   2016-12-07 11:17:00 2016-12-07 12:23:00      66.0              11    D
# 21   2016-12-07 15:46:00 2016-12-07 16:40:00      54.0              15    D
# 22   2016-12-07 18:00:00 2016-12-07 18:28:00      28.0              18    E
# 23   2016-07-13 08:17:29 2016-07-13 09:22:37      65.0               8    M
# 24   2016-07-13 21:54:18 2016-07-13 22:51:23      57.0              21    E
# 25   2016-07-14 21:23:03 2016-07-14 22:25:19      62.0              21    E
# 26   2016-07-15 02:41:38 2016-07-15 03:24:43      43.0               2   EM
# 27   2016-07-15 10:00:43 2016-07-15 10:53:06      52.0              10    M
# 28   2016-11-07 13:08:00 2016-11-07 13:49:00      41.0              13    D
# 29   2016-12-07 06:21:00 2016-12-07 07:10:00      49.0               6   EM
# ...                  ...                 ...       ...             ...  ...
# 6715 2016-07-15 22:34:01                 NaT       NaN              22    N
# 6716 2016-07-15 22:36:13                 NaT       NaN              22    N
# 6717 2016-07-15 22:37:37                 NaT       NaN              22    N
# 6718 2016-07-15 22:43:46                 NaT       NaN              22    N
# 6719 2016-07-15 22:49:33                 NaT       NaN              22    N
# 6720 2016-07-15 22:49:45                 NaT       NaN              22    N
# 6721 2016-07-15 22:51:18                 NaT       NaN              22    N
# 6722 2016-07-15 22:56:00                 NaT       NaN              22    N
# 6723 2016-07-15 22:58:15                 NaT       NaN              22    N
# 6724 2016-07-15 23:03:23                 NaT       NaN              23    N
# 6725 2016-07-15 23:08:14                 NaT       NaN              23    N
# 6726 2016-07-15 23:11:41                 NaT       NaN              23    N
# 6727 2016-07-15 23:14:36                 NaT       NaN              23    N
# 6728 2016-07-15 23:14:39                 NaT       NaN              23    N
# 6729 2016-07-15 23:16:48                 NaT       NaN              23    N
# 6730 2016-07-15 23:18:21                 NaT       NaN              23    N
# 6731 2016-07-15 23:21:53                 NaT       NaN              23    N
# 6732 2016-07-15 23:26:50                 NaT       NaN              23    N
# 6733 2016-07-15 23:27:55                 NaT       NaN              23    N
# 6734 2016-07-15 23:35:50                 NaT       NaN              23    N
# 6735 2016-07-15 23:39:15                 NaT       NaN              23    N
# 6736 2016-07-15 23:42:51                 NaT       NaN              23    N
# 6737 2016-07-15 23:43:54                 NaT       NaN              23    N
# 6738 2016-07-15 23:46:03                 NaT       NaN              23    N
# 6739 2016-07-15 23:46:20                 NaT       NaN              23    N
# 6740 2016-07-15 23:49:03                 NaT       NaN              23    N
# 6741 2016-07-15 23:50:05                 NaT       NaN              23    N
# 6742 2016-07-15 23:52:06                 NaT       NaN              23    N
# 6743 2016-07-15 23:54:39                 NaT       NaN              23    N
# 6744 2016-07-15 23:55:03                 NaT       NaN              23    N
#
#             Ride Type
# 0        Towards City
# 1        Towards City
# 2     Towards Airport
# 3        Towards City
# 4     Towards Airport
# 5        Towards City
# 6        Towards City
# 7        Towards City
# 8     Towards Airport
# 9     Towards Airport
# 10       Towards City
# 11    Towards Airport
# 12       Towards City
# 13    Towards Airport
# 14    Towards Airport
# 15       Towards City
# 16    Towards Airport
# 17       Towards City
# 18       Towards City
# 19       Towards City
# 20       Towards City
# 21       Towards City
# 22       Towards City
# 23       Towards City
# 24       Towards City
# 25    Towards Airport
# 26    Towards Airport
# 27    Towards Airport
# 28    Towards Airport
# 29       Towards City
# ...               ...
# 6715  Towards Airport
# 6716     Towards City
# 6717     Towards City
# 6718     Towards City
# 6719  Towards Airport
# 6720  Towards Airport
# 6721     Towards City
# 6722     Towards City
# 6723     Towards City
# 6724  Towards Airport
# 6725  Towards Airport
# 6726  Towards Airport
# 6727  Towards Airport
# 6728     Towards City
# 6729  Towards Airport
# 6730     Towards City
# 6731     Towards City
# 6732  Towards Airport
# 6733     Towards City
# 6734     Towards City
# 6735     Towards City
# 6736     Towards City
# 6737  Towards Airport
# 6738  Towards Airport
# 6739  Towards Airport
# 6740  Towards Airport
# 6741     Towards City
# 6742  Towards Airport
# 6743  Towards Airport
# 6744     Towards City
#
# [6745 rows x 10 columns]

# %%
#Data Analysis- validating the data frame for null values to get insights
uber.isnull().sum()
# Out:
# Request id              0
# Pickup point            0
# Driver id            2650
# Status                  0
# Request timestamp       0
# Drop timestamp       3914
# Duration             3914
# Requested Hour          0
# slot                    0
# Ride Type               0
# dtype: int64

# %%
#Univariate Analysis - slot wise request distribution 
uber_slot_count=uber.groupby('slot')['Request id'].count()
uber_slot_count
# Out:
# slot
# D      981
# E     2342
# EM    1421
# M     1503
# N      498
# Name: Request id, dtype: int64

# %%
# Data Visualization- Plot requests per timeslot using bar chart. 
plt.bar(uber.slot.unique(),uber_slot_count)

# put x and y labels, and the title
plt.xlabel("Time Slots")
plt.ylabel("Requests")
plt.title("Requests Vs Time Slots")

plt.show()

# We see that early morning (EM) and evening(E) have highest requests for cabs

# %%
#slot wise request distribution 
uber_slot_view=uber.groupby('Requested Hour')['Request id'].count()
uber_slot_view
# Out:
# Requested Hour
# 0      99
# 1      85
# 2      99
# 3      92
# 4     203
# 5     445
# 6     398
# 7     406
# 8     423
# 9     431
# 10    243
# 11    171
# 12    184
# 13    160
# 14    136
# 15    171
# 16    159
# 17    418
# 18    510
# 19    473
# 20    492
# 21    449
# 22    304
# 23    194
# Name: Request id, dtype: int64

# %%
#Set Style for plot frame
sns.set_style("whitegrid")

# %%
# Data Visualize - As date is involved, time plot is selected, plot that depicts number of requests over each hour slots.
plt.figure(figsize=(16, 8),dpi=70)
# time series plot
sns.tsplot(uber_slot_view)
plt.xlabel("Hour of Request")
plt.ylabel("Requests")
plt.show()

#Current visualization shows exactly the peak points of requests
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
#Data Analysis - Distribution of requests based on ride type over 24 hour timeline
uber_ridetype_view=uber.groupby(['Requested Hour','Ride Type'])['Request id'].count()
uber_ridetype_view
# Out:
# Requested Hour  Ride Type
# 0               Towards Airport     46
#                 Towards City        53
# 1               Towards Airport     43
#                 Towards City        42
# 2               Towards Airport     58
#                 Towards City        41
# 3               Towards Airport     47
#                 Towards City        45
# 4               Towards Airport    131
#                 Towards City        72
# 5               Towards Airport    353
#                 Towards City        92
# 6               Towards Airport    309
#                 Towards City        89
# 7               Towards Airport    323
#                 Towards City        83
# 8               Towards Airport    350
#                 Towards City        73
# 9               Towards Airport    342
#                 Towards City        89
# 10              Towards Airport    168
#                 Towards City        75
# 11              Towards Airport    107
#                 Towards City        64
# 12              Towards Airport     97
#                 Towards City        87
# 13              Towards Airport     95
#                 Towards City        65
# 14              Towards Airport     86
#                 Towards City        50
# 15              Towards Airport     95
#                 Towards City        76
# 16              Towards Airport     98
#                 Towards City        61
# 17              Towards Airport    110
#                 Towards City       308
# 18              Towards Airport    105
#                 Towards City       405
# 19              Towards Airport    107
#                 Towards City       366
# 20              Towards Airport    114
#                 Towards City       378
# 21              Towards Airport    106
#                 Towards City       343
# 22              Towards Airport    121
#                 Towards City       183
# 23              Towards Airport     96
#                 Towards City        98
# Name: Request id, dtype: int64

# %%
# Data Visualise - time plot that depicts number of requests from people towards airport over each hour slots.
plt.figure(figsize=(16, 8),dpi=70)
# time series plot
sns.tsplot(uber[uber['Ride Type']=="Towards Airport"].groupby('Requested Hour')['Request id'].count())
plt.xlabel("Hour of Request")
plt.ylabel("Requests")
plt.title("Requests Vs Direction of Ride-Towards Airport")
plt.show()

#Current visualization shows exactly the peak points of requests, specifically people commuting towards airport
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
# Data Visualise- time plot that depicts number of requests from people towards city over each hour slots.
plt.figure(figsize=(16, 8),dpi=70)
# time series plot
sns.tsplot(uber[uber['Ride Type']=="Towards City"].groupby('Requested Hour')['Request id'].count())
plt.xlabel("Hour of Request")
plt.ylabel("Requests Towards City")
plt.title("Requests Vs Direction of Ride- Towards City")
plt.show()

#Current visualization shows exactly the peak points of requests, specifically people commuting towards airport
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
#Data Analysis- Number of requests that were not serviced by uber - specifically by users who wish to available cab to go to airport
uber_reject_nocab_airport=uber[(uber['Ride Type']=="Towards Airport") & (uber['Status']=="No Cars Available")].groupby('Requested Hour')['Request id'].count()
uber_reject_nocab_airport
# Out:
# Requested Hour
# 0     26
# 1     27
# 2     32
# 3     26
# 4     40
# 5     81
# 6     82
# 7     60
# 8     86
# 9     76
# 10    52
# 11    31
# 12    30
# 13    32
# 14    30
# 15    35
# 16    37
# 17    17
# 18    13
# 19    15
# 20    15
# 21    11
# 22    38
# 23    45
# Name: Request id, dtype: int64

# %%
# Data Visualise- time plot that depicts number of requests from people towards airport over each hour slots, that potentially missed the ride
plt.figure(figsize=(16, 8),dpi=70)
# time series plot
sns.tsplot(uber_reject_nocab_airport)
plt.xlabel("Hour of Request")
plt.ylabel("Missed Requests")
plt.title("Unserviced Requests Over Timeline - Towards Airport")
plt.show()

#Current visualization shows exactly the peak points of requests, specifically people commuting towards airport missing the ride, clearly highlight the loss for uber
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
#Data Anaysis - Number of requests that were not serviced by uber - specifically by users who wish to available cab to go towards
uber_reject_nocab_city=uber[(uber['Ride Type']=="Towards City") & (uber['Status']=="No Cars Available")].groupby('Requested Hour')['Request id'].count()
uber_reject_nocab_city
# Out:
# Requested Hour
# 0      30
# 1      29
# 2      25
# 3      30
# 4      34
# 5       3
# 6       4
# 7       3
# 8       4
# 9       7
# 10     13
# 11     10
# 12     14
# 13     21
# 14      7
# 15     13
# 16      9
# 17    215
# 18    309
# 19    268
# 20    275
# 21    254
# 22    100
# 23     36
# Name: Request id, dtype: int64

# %%
# Data Visualise - time plot that depicts number of requests from people towards city over each hour slots, that potentially missed the ride
plt.figure(figsize=(16, 8),dpi=70)
# time series plot
sns.tsplot(uber_reject_nocab_city)
plt.xlabel("Hour of Request")
plt.ylabel("Missed Requests")
plt.title('Unserviced Requests Over Timeline-Towards City')
plt.show()

#Current visualization shows exactly the peak points of requests, specifically people commuting towards city missing the ride, clearly highlight the loss for uber
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
#Data Analysis- Number of requests that were successfully completed over timeslots, Towards City
uber_success_city=uber[(uber['Ride Type']=="Towards City") & (uber['Status']=="Trip Completed")].groupby('Requested Hour')['Request id'].count()
uber_success_city
# Out:
# Requested Hour
# 0     23
# 1     13
# 2     16
# 3     15
# 4     36
# 5     85
# 6     81
# 7     75
# 8     67
# 9     74
# 10    53
# 11    49
# 12    63
# 13    35
# 14    37
# 15    52
# 16    38
# 17    74
# 18    81
# 19    83
# 20    74
# 21    61
# 22    80
# 23    62
# Name: Request id, dtype: int64

# %%
#Data Analysis- Number of requests that were successfully completed over timeslots, Towards Airport
uber_success_airport=uber[(uber['Ride Type']=="Towards Airport") & (uber['Status']=="Trip Completed")].groupby('Requested Hour')['Request id'].count()
uber_success_airport
# Out:
# Requested Hour
# 0      17
# 1      12
# 2      21
# 3      19
# 4      42
# 5     100
# 6      86
# 7      99
# 8      88
# 9      99
# 10     63
# 11     66
# 12     58
# 13     54
# 14     51
# 15     50
# 16     53
# 17     77
# 18     83
# 19     83
# 20     87
# 21     81
# 22     74
# 23     41
# Name: Request id, dtype: int64

# %%
#Data Analysis- Univariate - Now analyzing differnt options available for trip status and see if further insights can be taken
uber_status=uber.groupby('Status')['Request id'].count()
uber_status
# Out:
# Status
# Cancelled            1264
# No Cars Available    2650
# Trip Completed       2831
# Name: Request id, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(10,8))
uber_status.plot(kind='pie', ax=ax)
plt.show()
#We see that there are 1264 requests that are in cancelled state. These were not considered earlier assuming users cancelled it

# %%
#Assumptions - If drivers persuade customers to cancel the requests, we need to consider it under rejected or no cabs available section. 
# Re analyzing based on new assumptions-  reploting the graphs including them.
statustypes=['No Cars Available', 'Cancelled']
uber_rejects_TowardAirport=uber[(uber['Ride Type']=="Towards Airport") & (uber.Status.isin(statustypes))].groupby('Requested Hour')['Request id'].count()
uber_rejects_TowardCity=uber[(uber['Ride Type']=="Towards City") & (uber.Status.isin(statustypes))].groupby('Requested Hour')['Request id'].count()

uber_rejects_TowardAirport
# Out:
# Requested Hour
# 0      29
# 1      31
# 2      37
# 3      28
# 4      89
# 5     253
# 6     223
# 7     224
# 8     262
# 9     243
# 10    105
# 11     41
# 12     39
# 13     41
# 14     35
# 15     45
# 16     45
# 17     33
# 18     22
# 19     24
# 20     27
# 21     25
# 22     47
# 23     55
# Name: Request id, dtype: int64

# %%
uber_rejects_TowardCity
# Out:
# Requested Hour
# 0      30
# 1      29
# 2      25
# 3      30
# 4      36
# 5       7
# 6       8
# 7       8
# 8       6
# 9      15
# 10     22
# 11     15
# 12     24
# 13     30
# 14     13
# 15     24
# 16     23
# 17    234
# 18    324
# 19    283
# 20    304
# 21    282
# 22    103
# 23     36
# Name: Request id, dtype: int64

# %%
# time series plot based on above assumptions- rejects towards airport

plt.figure(figsize=(16, 8),dpi=70)
sns.tsplot(uber_rejects_TowardAirport)
plt.xlabel("Hour of Request")
plt.ylabel("Missed Requests")
plt.title('Unserviced Requests Over Timeline-Towards Airport')
plt.show()
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
# time series plot based on above assumptions- rejects towards city

plt.figure(figsize=(16, 8),dpi=70)
sns.tsplot(uber_rejects_TowardCity)
plt.xlabel("Hour of Request")
plt.ylabel("Missed Requests")
plt.title('Unserviced Requests Over Timeline-Towards City')
plt.show()
# Out:
# C:\Technical\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
#Data Analysis on Ride type, time slot and Status of the booking-.
uber.groupby(['Ride Type','slot','Status',])['Request id'].count()
# Out:
# Ride Type        slot  Status
# Towards Airport  D     Cancelled              51
#                        No Cars Available     195
#                        Trip Completed        332
#                  E     Cancelled              60
#                        No Cars Available      71
#                        Trip Completed        411
#                  EM    Cancelled             376
#                        No Cars Available     314
#                        Trip Completed        297
#                  M     Cancelled             560
#                        No Cars Available     274
#                        Trip Completed        349
#                  N     Cancelled              19
#                        No Cars Available      83
#                        Trip Completed        115
# Towards City     D     Cancelled              55
#                        No Cars Available      74
#                        Trip Completed        274
#                  E     Cancelled             106
#                        No Cars Available    1321
#                        Trip Completed        373
#                  EM    Cancelled              10
#                        No Cars Available     155
#                        Trip Completed        269
#                  M     Cancelled              24
#                        No Cars Available      27
#                        Trip Completed        269
#                  N     Cancelled               3
#                        No Cars Available     136
#                        Trip Completed        142
# Name: Request id, dtype: int64

# %%
#Visualise - Plotting bar graph on above analysis
fig, ax=plt.subplots(figsize=(18,8))
uber.groupby(['Ride Type','slot','Status',])['Request id'].count().unstack().plot(kind='bar', stacked=True,ax=ax)
plt.show()
# Outcomes/assumptions -
# Clearly highlights the problem that customers are not getting the cars towards city in evening time.
# Also highlights Highest cancellation during morning time

# %%
# Analysis on Driver perspective - Plotting above analysis in graph
fig, ax=plt.subplots(figsize=(100,15))
uber.groupby(['Driver id','Status'])['Request id'].count().unstack().plot(kind='bar', stacked=True,ax=ax)
plt.show()
# Outcomes -
# We could see some drivers cancelling more due to unwillingness based on customer location and traffic routes issues

# %%
# Analysis on Driver perspective - Drivers that Cancelled requests in peak time slots, in decending order
uber[(uber.Status=="Cancelled") & (uber.slot.isin(["M","E","EM"]))].groupby(['Driver id','Ride Type','slot','Status',])['Request id'].count().reset_index(name='count').sort_values(['count'],ascending=False)
# We could see list of drivers cancelling the cabs in the morning possibly due to late night rides.
# Out:
#      Driver id        Ride Type slot     Status  count
# 318      142.0  Towards Airport    M  Cancelled      8
# 304      138.0  Towards Airport    M  Cancelled      7
# 182       84.0  Towards Airport    M  Cancelled      6
# 366      166.0  Towards Airport   EM  Cancelled      5
# 111       50.0  Towards Airport   EM  Cancelled      5
# 132       59.0  Towards Airport    M  Cancelled      5
# 57        27.0  Towards Airport    M  Cancelled      5
# 419      190.0  Towards Airport    M  Cancelled      5
# 390      176.0  Towards Airport    M  Cancelled      5
# 96        44.0  Towards Airport    M  Cancelled      5
# 541      249.0  Towards Airport    M  Cancelled      5
# 392      177.0  Towards Airport    M  Cancelled      5
# 135       62.0  Towards Airport   EM  Cancelled      5
# 288      131.0  Towards Airport    M  Cancelled      5
# 43        20.0  Towards Airport    M  Cancelled      5
# 451      205.0  Towards Airport   EM  Cancelled      5
# 452      206.0  Towards Airport   EM  Cancelled      5
# 87        39.0  Towards Airport    M  Cancelled      5
# 613      284.0  Towards Airport    M  Cancelled      4
# 464      212.0  Towards Airport    M  Cancelled      4
# 48        22.0  Towards Airport    M  Cancelled      4
# 616      285.0  Towards Airport    M  Cancelled      4
# 471      216.0  Towards Airport    M  Cancelled      4
# 460      210.0     Towards City    E  Cancelled      4
# 309      139.0  Towards Airport    M  Cancelled      4
# 572      267.0  Towards Airport   EM  Cancelled      4
# 585      271.0  Towards Airport    M  Cancelled      4
# 98        45.0  Towards Airport    M  Cancelled      4
# 534      245.0  Towards Airport    M  Cancelled      4
# 264      120.0  Towards Airport    M  Cancelled      4
# ..         ...              ...  ...        ...    ...
# 254      114.0     Towards City    E  Cancelled      1
# 306      138.0     Towards City    M  Cancelled      1
# 278      128.0  Towards Airport   EM  Cancelled      1
# 305      138.0     Towards City    E  Cancelled      1
# 303      137.0     Towards City    E  Cancelled      1
# 300      137.0  Towards Airport    E  Cancelled      1
# 299      136.0     Towards City   EM  Cancelled      1
# 297      136.0  Towards Airport    M  Cancelled      1
# 293      134.0  Towards Airport   EM  Cancelled      1
# 292      133.0  Towards Airport   EM  Cancelled      1
# 291      133.0  Towards Airport    E  Cancelled      1
# 290      132.0     Towards City   EM  Cancelled      1
# 286      130.0     Towards City    E  Cancelled      1
# 280      128.0     Towards City    M  Cancelled      1
# 279      128.0  Towards Airport    M  Cancelled      1
# 277      127.0     Towards City    M  Cancelled      1
# 255      115.0  Towards Airport    M  Cancelled      1
# 275      126.0     Towards City    E  Cancelled      1
# 272      125.0  Towards Airport   EM  Cancelled      1
# 271      124.0  Towards Airport    M  Cancelled      1
# 269      123.0  Towards Airport    M  Cancelled      1
# 268      122.0  Towards Airport    E  Cancelled      1
# 266      121.0  Towards Airport    E  Cancelled      1
# 265      120.0     Towards City    E  Cancelled      1
# 263      119.0     Towards City   EM  Cancelled      1
# 261      119.0  Towards Airport   EM  Cancelled      1
# 258      117.0  Towards Airport   EM  Cancelled      1
# 257      116.0  Towards Airport    M  Cancelled      1
# 256      116.0  Towards Airport   EM  Cancelled      1
# 647      300.0  Towards Airport   EM  Cancelled      1
#
# [648 rows x 5 columns]

# %%
#Extract data frame for tableau 
Uber2Excel=pd.ExcelWriter('uber_cleaned_frame.xlsx')
uber.to_excel(Uber2Excel,'Sheet1')
Uber2Excel.save()
